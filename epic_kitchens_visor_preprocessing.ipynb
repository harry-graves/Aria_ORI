# %% [markdown]
# <a href="https://colab.research.google.com/github/harry-graves/Aria_ORI/blob/main/epic_kitchens_visor_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EPIC-KITCHENS-VISOR dataset preprocessing
# This script separates frames from the EPIC-KITCHENS-VISOR dataset into ones containing a hand-object interaction, and those that do not, separately for the left and right hand.
#
# The dataset was NOT created using the Project Aria glasses and hence eye-tracking data is not available. This data can therefore not be used on a model conditioned on eye-tracking data, but is useful as a demonstration for image classification.
#
# Furthermore, the images are not square; the majority are 1920x1080, and do not contain the vignette that the Aria glasses RGB frames contain. Therefore, the model is unlikely to generalise to frames recorded with the Aria glasses.

# %%
import numpy as np
import tensorflow as tf
import os
import json
import zipfile
from google.colab import drive
import shutil

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
training_filenames = ['P01_01', 'P01_03', 'P01_05', 'P01_07', 'P01_09', 'P01_103', 'P01_104', 'P01_14', 'P02_01', 'P02_03', 'P02_07', 'P02_101', 'P02_102', 'P02_107', 'P02_109', 'P02_121', 'P02_122', 'P02_124', 'P02_128', 'P02_130', 'P02_132', 'P02_135', 'P03_03', 'P03_04', 'P03_05', 'P03_101', 'P03_11', 'P03_112', 'P03_113', 'P03_123', 'P03_13', 'P03_17', 'P03_23', 'P03_24', 'P04_02', 'P04_03', 'P04_04', 'P04_05', 'P04_101', 'P04_109', 'P04_11', 'P04_110', 'P04_114', 'P04_12', 'P04_121', 'P04_21', 'P04_25', 'P04_26', 'P04_33', 'P05_01', 'P05_08', 'P06_01', 'P06_07', 'P06_09', 'P06_101', 'P06_102', 'P06_103', 'P06_107', 'P06_11', 'P06_110', 'P06_12', 'P06_13', 'P06_14', 'P07_08', 'P08_09', 'P08_16', 'P08_21', 'P10_04', 'P11_101', 'P11_102', 'P11_103', 'P11_104', 'P11_105', 'P11_107', 'P11_16', 'P12_02', 'P12_03', 'P12_101', 'P13_10', 'P14_05', 'P15_02', 'P17_01', 'P18_03', 'P18_06', 'P18_07', 'P20_03', 'P22_01', 'P22_07', 'P22_117', 'P23_02', 'P23_05', 'P24_05', 'P24_08', 'P25_107', 'P26_110', 'P27_101', 'P28_06', 'P28_101', 'P28_103', 'P28_109', 'P28_110', 'P28_112', 'P28_113', 'P28_13', 'P28_14', 'P30_05', 'P30_101', 'P30_107', 'P30_111', 'P30_112', 'P32_01', 'P35_105', 'P35_109', 'P37_101', 'P37_103']

json_base_url = "https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/"
zip_base_url = "https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/"

# !mkdir annotations_train
# %cd annotations_train/
for suffix in training_filenames:
  url = f"{json_base_url}{suffix}.json"
  # !wget {url}
# %cd ..

# !mkdir images_train
# %cd images_train/
for suffix in training_filenames:
    url = f"{zip_base_url}{suffix[0:3]}/{suffix}.zip"
    # !wget {url}
# %cd ..
# Out:
# /content/annotations_train
# --2024-12-24 10:56:52--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P01_01.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17282261 (16M) [application/json]
# Saving to: ‘P01_01.json’
#
# P01_01.json         100%[===================>]  16.48M   972KB/s    in 18s
#
# 2024-12-24 10:57:11 (915 KB/s) - ‘P01_01.json’ saved [17282261/17282261]
#
# --2024-12-24 10:57:11--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P01_03.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 271379 (265K) [application/json]
# Saving to: ‘P01_03.json’
#
# P01_03.json         100%[===================>] 265.02K   253KB/s    in 1.0s
#
# 2024-12-24 10:57:13 (253 KB/s) - ‘P01_03.json’ saved [271379/271379]
#
# --2024-12-24 10:57:13--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P01_05.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6385857 (6.1M) [application/json]
# Saving to: ‘P01_05.json’
#
# P01_05.json         100%[===================>]   6.09M   969KB/s    in 6.7s
#
# 2024-12-24 10:57:20 (932 KB/s) - ‘P01_05.json’ saved [6385857/6385857]
#
# --2024-12-24 10:57:20--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P01_07.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 886173 (865K) [application/json]
# Saving to: ‘P01_07.json’
#
# P01_07.json         100%[===================>] 865.40K   656KB/s    in 1.3s
#
# 2024-12-24 10:57:22 (656 KB/s) - ‘P01_07.json’ saved [886173/886173]
#
# --2024-12-24 10:57:22--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P01_09.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23220642 (22M) [application/json]
# Saving to: ‘P01_09.json’
#
# P01_09.json         100%[===================>]  22.14M   962KB/s    in 24s
#
# 2024-12-24 10:57:47 (949 KB/s) - ‘P01_09.json’ saved [23220642/23220642]
#
# --2024-12-24 10:57:47--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P01_103.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1879960 (1.8M) [application/json]
# Saving to: ‘P01_103.json’
#
# P01_103.json        100%[===================>]   1.79M   873KB/s    in 2.1s
#
# 2024-12-24 10:57:49 (873 KB/s) - ‘P01_103.json’ saved [1879960/1879960]
#
# --2024-12-24 10:57:49--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P01_104.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3006463 (2.9M) [application/json]
# Saving to: ‘P01_104.json’
#
# P01_104.json        100%[===================>]   2.87M   894KB/s    in 3.3s
#
# 2024-12-24 10:57:53 (894 KB/s) - ‘P01_104.json’ saved [3006463/3006463]
#
# --2024-12-24 10:57:53--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P01_14.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8599491 (8.2M) [application/json]
# Saving to: ‘P01_14.json’
#
# P01_14.json         100%[===================>]   8.20M   972KB/s    in 9.0s
#
# 2024-12-24 10:58:03 (930 KB/s) - ‘P01_14.json’ saved [8599491/8599491]
#
# --2024-12-24 10:58:03--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P02_01.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1215169 (1.2M) [application/json]
# Saving to: ‘P02_01.json’
#
# P02_01.json         100%[===================>]   1.16M   822KB/s    in 1.4s
#
# 2024-12-24 10:58:05 (822 KB/s) - ‘P02_01.json’ saved [1215169/1215169]
#
# --2024-12-24 10:58:05--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P02_03.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15702836 (15M) [application/json]
# Saving to: ‘P02_03.json’
#
# P02_03.json         100%[===================>]  14.97M   983KB/s    in 16s
#
# 2024-12-24 10:58:22 (952 KB/s) - ‘P02_03.json’ saved [15702836/15702836]
#
# --2024-12-24 10:58:22--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P02_07.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1991793 (1.9M) [application/json]
# Saving to: ‘P02_07.json’
#
# P02_07.json         100%[===================>]   1.90M   867KB/s    in 2.2s
#
# 2024-12-24 10:58:25 (867 KB/s) - ‘P02_07.json’ saved [1991793/1991793]
#
# --2024-12-24 10:58:25--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P02_101.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3315585 (3.2M) [application/json]
# Saving to: ‘P02_101.json’
#
# P02_101.json        100%[===================>]   3.16M   914KB/s    in 3.5s
#
# 2024-12-24 10:58:29 (914 KB/s) - ‘P02_101.json’ saved [3315585/3315585]
#
# --2024-12-24 10:58:29--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P02_102.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2299515 (2.2M) [application/json]
# Saving to: ‘P02_102.json’
#
# P02_102.json        100%[===================>]   2.19M   901KB/s    in 2.5s
#
# 2024-12-24 10:58:32 (901 KB/s) - ‘P02_102.json’ saved [2299515/2299515]
#
# --2024-12-24 10:58:32--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P02_107.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 960201 (938K) [application/json]
# Saving to: ‘P02_107.json’
#
# P02_107.json        100%[===================>] 937.70K   793KB/s    in 1.2s
#
# 2024-12-24 10:58:34 (793 KB/s) - ‘P02_107.json’ saved [960201/960201]
#
# --2024-12-24 10:58:34--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P02_109.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5784218 (5.5M) [application/json]
# Saving to: ‘P02_109.json’
#
# P02_109.json        100%[===================>]   5.52M   996KB/s    in 6.0s
#
# 2024-12-24 10:58:41 (936 KB/s) - ‘P02_109.json’ saved [5784218/5784218]
#
# --2024-12-24 10:58:41--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P02_121.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2292376 (2.2M) [application/json]
# Saving to: ‘P02_121.json’
#
# P02_121.json        100%[===================>]   2.19M   899KB/s    in 2.5s
#
# 2024-12-24 10:58:44 (899 KB/s) - ‘P02_121.json’ saved [2292376/2292376]
#
# --2024-12-24 10:58:44--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P02_122.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4932064 (4.7M) [application/json]
# Saving to: ‘P02_122.json’
#
# P02_122.json        100%[===================>]   4.70M   964KB/s    in 5.2s
#
# 2024-12-24 10:58:50 (918 KB/s) - ‘P02_122.json’ saved [4932064/4932064]
#
# --2024-12-24 10:58:50--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P02_124.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2090465 (2.0M) [application/json]
# Saving to: ‘P02_124.json’
#
# P02_124.json        100%[===================>]   1.99M   865KB/s    in 2.4s
#
# 2024-12-24 10:58:53 (865 KB/s) - ‘P02_124.json’ saved [2090465/2090465]
#
# --2024-12-24 10:58:53--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P02_128.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1822450 (1.7M) [application/json]
# Saving to: ‘P02_128.json’
#
# P02_128.json        100%[===================>]   1.74M   846KB/s    in 2.1s
#
# 2024-12-24 10:58:55 (846 KB/s) - ‘P02_128.json’ saved [1822450/1822450]
#
# --2024-12-24 10:58:55--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P02_130.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8756529 (8.4M) [application/json]
# Saving to: ‘P02_130.json’
#
# P02_130.json        100%[===================>]   8.35M   969KB/s    in 9.1s
#
# 2024-12-24 10:59:05 (938 KB/s) - ‘P02_130.json’ saved [8756529/8756529]
#
# --2024-12-24 10:59:05--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P02_132.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2950744 (2.8M) [application/json]
# Saving to: ‘P02_132.json’
#
# P02_132.json        100%[===================>]   2.81M   873KB/s    in 3.3s
#
# 2024-12-24 10:59:09 (873 KB/s) - ‘P02_132.json’ saved [2950744/2950744]
#
# --2024-12-24 10:59:09--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P02_135.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2178695 (2.1M) [application/json]
# Saving to: ‘P02_135.json’
#
# P02_135.json        100%[===================>]   2.08M   901KB/s    in 2.4s
#
# 2024-12-24 10:59:12 (901 KB/s) - ‘P02_135.json’ saved [2178695/2178695]
#
# --2024-12-24 10:59:12--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P03_03.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 407876 (398K) [application/json]
# Saving to: ‘P03_03.json’
#
# P03_03.json         100%[===================>] 398.32K   607KB/s    in 0.7s
#
# 2024-12-24 10:59:14 (607 KB/s) - ‘P03_03.json’ saved [407876/407876]
#
# --2024-12-24 10:59:14--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P03_04.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8984438 (8.6M) [application/json]
# Saving to: ‘P03_04.json’
#
# P03_04.json         100%[===================>]   8.57M   977KB/s    in 9.4s
#
# 2024-12-24 10:59:24 (937 KB/s) - ‘P03_04.json’ saved [8984438/8984438]
#
# --2024-12-24 10:59:24--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P03_05.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2114250 (2.0M) [application/json]
# Saving to: ‘P03_05.json’
#
# P03_05.json         100%[===================>]   2.02M   520KB/s    in 4.0s
#
# 2024-12-24 10:59:28 (520 KB/s) - ‘P03_05.json’ saved [2114250/2114250]
#
# --2024-12-24 10:59:28--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P03_101.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9338290 (8.9M) [application/json]
# Saving to: ‘P03_101.json’
#
# P03_101.json        100%[===================>]   8.91M   978KB/s    in 9.7s
#
# 2024-12-24 10:59:39 (941 KB/s) - ‘P03_101.json’ saved [9338290/9338290]
#
# --2024-12-24 10:59:39--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P03_11.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 464025 (453K) [application/json]
# Saving to: ‘P03_11.json’
#
# P03_11.json         100%[===================>] 453.15K   575KB/s    in 0.8s
#
# 2024-12-24 10:59:40 (575 KB/s) - ‘P03_11.json’ saved [464025/464025]
#
# --2024-12-24 10:59:40--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P03_112.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3269009 (3.1M) [application/json]
# Saving to: ‘P03_112.json’
#
# P03_112.json        100%[===================>]   3.12M   901KB/s    in 3.5s
#
# 2024-12-24 10:59:44 (901 KB/s) - ‘P03_112.json’ saved [3269009/3269009]
#
# --2024-12-24 10:59:44--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P03_113.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2651131 (2.5M) [application/json]
# Saving to: ‘P03_113.json’
#
# P03_113.json        100%[===================>]   2.53M   897KB/s    in 2.9s
#
# 2024-12-24 10:59:48 (897 KB/s) - ‘P03_113.json’ saved [2651131/2651131]
#
# --2024-12-24 10:59:48--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P03_123.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3938996 (3.8M) [application/json]
# Saving to: ‘P03_123.json’
#
# P03_123.json        100%[===================>]   3.76M   905KB/s    in 4.2s
#
# 2024-12-24 10:59:53 (905 KB/s) - ‘P03_123.json’ saved [3938996/3938996]
#
# --2024-12-24 10:59:53--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P03_13.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 244454 (239K) [application/json]
# Saving to: ‘P03_13.json’
#
# P03_13.json         100%[===================>] 238.72K   455KB/s    in 0.5s
#
# 2024-12-24 10:59:54 (455 KB/s) - ‘P03_13.json’ saved [244454/244454]
#
# --2024-12-24 10:59:54--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P03_17.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 814697 (796K) [application/json]
# Saving to: ‘P03_17.json’
#
# P03_17.json         100%[===================>] 795.60K   758KB/s    in 1.0s
#
# 2024-12-24 10:59:56 (758 KB/s) - ‘P03_17.json’ saved [814697/814697]
#
# --2024-12-24 10:59:56--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P03_23.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2601327 (2.5M) [application/json]
# Saving to: ‘P03_23.json’
#
# P03_23.json         100%[===================>]   2.48M   880KB/s    in 2.9s
#
# 2024-12-24 10:59:59 (880 KB/s) - ‘P03_23.json’ saved [2601327/2601327]
#
# --2024-12-24 10:59:59--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P03_24.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5469496 (5.2M) [application/json]
# Saving to: ‘P03_24.json’
#
# P03_24.json         100%[===================>]   5.22M   992KB/s    in 5.6s
#
# 2024-12-24 11:00:06 (947 KB/s) - ‘P03_24.json’ saved [5469496/5469496]
#
# --2024-12-24 11:00:06--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P04_02.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10952358 (10M) [application/json]
# Saving to: ‘P04_02.json’
#
# P04_02.json         100%[===================>]  10.44M   956KB/s    in 11s
#
# 2024-12-24 11:00:18 (948 KB/s) - ‘P04_02.json’ saved [10952358/10952358]
#
# --2024-12-24 11:00:18--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P04_03.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7186156 (6.9M) [application/json]
# Saving to: ‘P04_03.json’
#
# P04_03.json         100%[===================>]   6.85M   980KB/s    in 7.5s
#
# 2024-12-24 11:00:26 (932 KB/s) - ‘P04_03.json’ saved [7186156/7186156]
#
# --2024-12-24 11:00:26--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P04_04.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6396182 (6.1M) [application/json]
# Saving to: ‘P04_04.json’
#
# P04_04.json         100%[===================>]   6.10M   981KB/s    in 6.7s
#
# 2024-12-24 11:00:33 (928 KB/s) - ‘P04_04.json’ saved [6396182/6396182]
#
# --2024-12-24 11:00:33--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P04_05.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17633707 (17M) [application/json]
# Saving to: ‘P04_05.json’
#
# P04_05.json         100%[===================>]  16.82M   978KB/s    in 18s
#
# 2024-12-24 11:00:52 (958 KB/s) - ‘P04_05.json’ saved [17633707/17633707]
#
# --2024-12-24 11:00:52--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P04_101.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5412365 (5.2M) [application/json]
# Saving to: ‘P04_101.json’
#
# P04_101.json        100%[===================>]   5.16M   985KB/s    in 5.6s
#
# 2024-12-24 11:00:58 (937 KB/s) - ‘P04_101.json’ saved [5412365/5412365]
#
# --2024-12-24 11:00:58--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P04_109.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17386427 (17M) [application/json]
# Saving to: ‘P04_109.json’
#
# P04_109.json        100%[===================>]  16.58M   950KB/s    in 18s
#
# 2024-12-24 11:01:17 (951 KB/s) - ‘P04_109.json’ saved [17386427/17386427]
#
# --2024-12-24 11:01:17--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P04_11.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1186420 (1.1M) [application/json]
# Saving to: ‘P04_11.json’
#
# P04_11.json         100%[===================>]   1.13M   798KB/s    in 1.5s
#
# 2024-12-24 11:01:19 (798 KB/s) - ‘P04_11.json’ saved [1186420/1186420]
#
# --2024-12-24 11:01:19--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P04_110.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22578742 (22M) [application/json]
# Saving to: ‘P04_110.json’
#
# P04_110.json        100%[===================>]  21.53M   965KB/s    in 23s
#
# 2024-12-24 11:01:43 (952 KB/s) - ‘P04_110.json’ saved [22578742/22578742]
#
# --2024-12-24 11:01:43--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P04_114.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2728430 (2.6M) [application/json]
# Saving to: ‘P04_114.json’
#
# P04_114.json        100%[===================>]   2.60M   911KB/s    in 2.9s
#
# 2024-12-24 11:01:46 (911 KB/s) - ‘P04_114.json’ saved [2728430/2728430]
#
# --2024-12-24 11:01:46--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P04_12.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 418124 (408K) [application/json]
# Saving to: ‘P04_12.json’
#
# P04_12.json         100%[===================>] 408.32K   622KB/s    in 0.7s
#
# 2024-12-24 11:01:48 (622 KB/s) - ‘P04_12.json’ saved [418124/418124]
#
# --2024-12-24 11:01:48--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P04_121.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21894542 (21M) [application/json]
# Saving to: ‘P04_121.json’
#
# P04_121.json        100%[===================>]  20.88M   986KB/s    in 22s
#
# 2024-12-24 11:02:11 (957 KB/s) - ‘P04_121.json’ saved [21894542/21894542]
#
# --2024-12-24 11:02:11--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P04_21.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 672839 (657K) [application/json]
# Saving to: ‘P04_21.json’
#
# P04_21.json         100%[===================>] 657.07K   712KB/s    in 0.9s
#
# 2024-12-24 11:02:12 (712 KB/s) - ‘P04_21.json’ saved [672839/672839]
#
# --2024-12-24 11:02:12--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P04_25.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1199470 (1.1M) [application/json]
# Saving to: ‘P04_25.json’
#
# P04_25.json         100%[===================>]   1.14M   807KB/s    in 1.5s
#
# 2024-12-24 11:02:14 (807 KB/s) - ‘P04_25.json’ saved [1199470/1199470]
#
# --2024-12-24 11:02:15--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P04_26.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 80944 (79K) [application/json]
# Saving to: ‘P04_26.json’
#
# P04_26.json         100%[===================>]  79.05K   300KB/s    in 0.3s
#
# 2024-12-24 11:02:15 (300 KB/s) - ‘P04_26.json’ saved [80944/80944]
#
# --2024-12-24 11:02:15--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P04_33.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1156322 (1.1M) [application/json]
# Saving to: ‘P04_33.json’
#
# P04_33.json         100%[===================>]   1.10M   783KB/s    in 1.4s
#
# 2024-12-24 11:02:17 (783 KB/s) - ‘P04_33.json’ saved [1156322/1156322]
#
# --2024-12-24 11:02:18--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P05_01.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 937398 (915K) [application/json]
# Saving to: ‘P05_01.json’
#
# P05_01.json         100%[===================>] 915.43K   698KB/s    in 1.3s
#
# 2024-12-24 11:02:19 (698 KB/s) - ‘P05_01.json’ saved [937398/937398]
#
# --2024-12-24 11:02:19--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P05_08.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3224021 (3.1M) [application/json]
# Saving to: ‘P05_08.json’
#
# P05_08.json         100%[===================>]   3.07M   880KB/s    in 3.6s
#
# 2024-12-24 11:02:24 (880 KB/s) - ‘P05_08.json’ saved [3224021/3224021]
#
# --2024-12-24 11:02:24--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P06_01.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 598828 (585K) [application/json]
# Saving to: ‘P06_01.json’
#
# P06_01.json         100%[===================>] 584.79K   633KB/s    in 0.9s
#
# 2024-12-24 11:02:26 (633 KB/s) - ‘P06_01.json’ saved [598828/598828]
#
# --2024-12-24 11:02:26--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P06_07.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8751831 (8.3M) [application/json]
# Saving to: ‘P06_07.json’
#
# P06_07.json         100%[===================>]   8.35M   966KB/s    in 9.2s
#
# 2024-12-24 11:02:35 (933 KB/s) - ‘P06_07.json’ saved [8751831/8751831]
#
# --2024-12-24 11:02:35--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P06_09.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4451700 (4.2M) [application/json]
# Saving to: ‘P06_09.json’
#
# P06_09.json         100%[===================>]   4.25M   884KB/s    in 4.9s
#
# 2024-12-24 11:02:41 (884 KB/s) - ‘P06_09.json’ saved [4451700/4451700]
#
# --2024-12-24 11:02:41--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P06_101.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14540937 (14M) [application/json]
# Saving to: ‘P06_101.json’
#
# P06_101.json        100%[===================>]  13.87M   589KB/s    in 17s
#
# 2024-12-24 11:02:59 (830 KB/s) - ‘P06_101.json’ saved [14540937/14540937]
#
# --2024-12-24 11:02:59--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P06_102.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3324618 (3.2M) [application/json]
# Saving to: ‘P06_102.json’
#
# P06_102.json        100%[===================>]   3.17M   916KB/s    in 3.5s
#
# 2024-12-24 11:03:03 (916 KB/s) - ‘P06_102.json’ saved [3324618/3324618]
#
# --2024-12-24 11:03:03--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P06_103.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3913178 (3.7M) [application/json]
# Saving to: ‘P06_103.json’
#
# P06_103.json        100%[===================>]   3.73M   926KB/s    in 4.3s
#
# 2024-12-24 11:03:08 (883 KB/s) - ‘P06_103.json’ saved [3913178/3913178]
#
# --2024-12-24 11:03:08--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P06_107.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2198041 (2.1M) [application/json]
# Saving to: ‘P06_107.json’
#
# P06_107.json        100%[===================>]   2.10M   856KB/s    in 2.5s
#
# 2024-12-24 11:03:11 (856 KB/s) - ‘P06_107.json’ saved [2198041/2198041]
#
# --2024-12-24 11:03:11--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P06_11.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 798354 (780K) [application/json]
# Saving to: ‘P06_11.json’
#
# P06_11.json         100%[===================>] 779.64K   844KB/s    in 0.9s
#
# 2024-12-24 11:03:12 (844 KB/s) - ‘P06_11.json’ saved [798354/798354]
#
# --2024-12-24 11:03:13--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P06_110.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 273095 (267K) [application/json]
# Saving to: ‘P06_110.json’
#
# P06_110.json        100%[===================>] 266.69K   673KB/s    in 0.4s
#
# 2024-12-24 11:03:14 (673 KB/s) - ‘P06_110.json’ saved [273095/273095]
#
# --2024-12-24 11:03:14--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P06_12.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 667896 (652K) [application/json]
# Saving to: ‘P06_12.json’
#
# P06_12.json         100%[===================>] 652.24K   710KB/s    in 0.9s
#
# 2024-12-24 11:03:15 (710 KB/s) - ‘P06_12.json’ saved [667896/667896]
#
# --2024-12-24 11:03:15--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P06_13.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3417524 (3.3M) [application/json]
# Saving to: ‘P06_13.json’
#
# P06_13.json         100%[===================>]   3.26M   903KB/s    in 3.7s
#
# 2024-12-24 11:03:19 (903 KB/s) - ‘P06_13.json’ saved [3417524/3417524]
#
# --2024-12-24 11:03:19--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P06_14.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 658192 (643K) [application/json]
# Saving to: ‘P06_14.json’
#
# P06_14.json         100%[===================>] 642.77K   699KB/s    in 0.9s
#
# 2024-12-24 11:03:21 (699 KB/s) - ‘P06_14.json’ saved [658192/658192]
#
# --2024-12-24 11:03:21--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P07_08.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 556856 (544K) [application/json]
# Saving to: ‘P07_08.json’
#
# P07_08.json         100%[===================>] 543.80K   686KB/s    in 0.8s
#
# 2024-12-24 11:03:22 (686 KB/s) - ‘P07_08.json’ saved [556856/556856]
#
# --2024-12-24 11:03:22--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P08_09.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3959492 (3.8M) [application/json]
# Saving to: ‘P08_09.json’
#
# P08_09.json         100%[===================>]   3.78M   888KB/s    in 4.4s
#
# 2024-12-24 11:03:27 (888 KB/s) - ‘P08_09.json’ saved [3959492/3959492]
#
# --2024-12-24 11:03:27--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P08_16.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5314429 (5.1M) [application/json]
# Saving to: ‘P08_16.json’
#
# P08_16.json         100%[===================>]   5.07M   964KB/s    in 5.6s
#
# 2024-12-24 11:03:34 (919 KB/s) - ‘P08_16.json’ saved [5314429/5314429]
#
# --2024-12-24 11:03:34--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P08_21.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9943586 (9.5M) [application/json]
# Saving to: ‘P08_21.json’
#
# P08_21.json         100%[===================>]   9.48M   986KB/s    in 10s
#
# 2024-12-24 11:03:45 (943 KB/s) - ‘P08_21.json’ saved [9943586/9943586]
#
# --2024-12-24 11:03:45--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P10_04.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14225993 (14M) [application/json]
# Saving to: ‘P10_04.json’
#
# P10_04.json         100%[===================>]  13.57M   983KB/s    in 15s
#
# 2024-12-24 11:04:00 (947 KB/s) - ‘P10_04.json’ saved [14225993/14225993]
#
# --2024-12-24 11:04:00--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P11_101.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1018176 (994K) [application/json]
# Saving to: ‘P11_101.json’
#
# P11_101.json        100%[===================>] 994.31K   837KB/s    in 1.2s
#
# 2024-12-24 11:04:02 (837 KB/s) - ‘P11_101.json’ saved [1018176/1018176]
#
# --2024-12-24 11:04:02--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P11_102.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1325239 (1.3M) [application/json]
# Saving to: ‘P11_102.json’
#
# P11_102.json        100%[===================>]   1.26M   817KB/s    in 1.6s
#
# 2024-12-24 11:04:04 (817 KB/s) - ‘P11_102.json’ saved [1325239/1325239]
#
# --2024-12-24 11:04:04--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P11_103.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2219478 (2.1M) [application/json]
# Saving to: ‘P11_103.json’
#
# P11_103.json        100%[===================>]   2.12M   912KB/s    in 2.4s
#
# 2024-12-24 11:04:07 (912 KB/s) - ‘P11_103.json’ saved [2219478/2219478]
#
# --2024-12-24 11:04:07--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P11_104.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8083170 (7.7M) [application/json]
# Saving to: ‘P11_104.json’
#
# P11_104.json        100%[===================>]   7.71M   969KB/s    in 8.4s
#
# 2024-12-24 11:04:16 (945 KB/s) - ‘P11_104.json’ saved [8083170/8083170]
#
# --2024-12-24 11:04:16--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P11_105.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2114210 (2.0M) [application/json]
# Saving to: ‘P11_105.json’
#
# P11_105.json        100%[===================>]   2.02M   868KB/s    in 2.4s
#
# 2024-12-24 11:04:19 (868 KB/s) - ‘P11_105.json’ saved [2114210/2114210]
#
# --2024-12-24 11:04:19--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P11_107.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 605833 (592K) [application/json]
# Saving to: ‘P11_107.json’
#
# P11_107.json        100%[===================>] 591.63K   750KB/s    in 0.8s
#
# 2024-12-24 11:04:21 (750 KB/s) - ‘P11_107.json’ saved [605833/605833]
#
# --2024-12-24 11:04:21--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P11_16.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1895125 (1.8M) [application/json]
# Saving to: ‘P11_16.json’
#
# P11_16.json         100%[===================>]   1.81M   830KB/s    in 2.2s
#
# 2024-12-24 11:04:24 (830 KB/s) - ‘P11_16.json’ saved [1895125/1895125]
#
# --2024-12-24 11:04:24--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P12_02.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5726460 (5.5M) [application/json]
# Saving to: ‘P12_02.json’
#
# P12_02.json         100%[===================>]   5.46M   984KB/s    in 6.0s
#
# 2024-12-24 11:04:30 (927 KB/s) - ‘P12_02.json’ saved [5726460/5726460]
#
# --2024-12-24 11:04:30--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P12_03.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3786094 (3.6M) [application/json]
# Saving to: ‘P12_03.json’
#
# P12_03.json         100%[===================>]   3.61M   934KB/s    in 4.0s
#
# 2024-12-24 11:04:35 (934 KB/s) - ‘P12_03.json’ saved [3786094/3786094]
#
# --2024-12-24 11:04:35--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P12_101.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17732104 (17M) [application/json]
# Saving to: ‘P12_101.json’
#
# P12_101.json        100%[===================>]  16.91M   989KB/s    in 18s
#
# 2024-12-24 11:04:54 (956 KB/s) - ‘P12_101.json’ saved [17732104/17732104]
#
# --2024-12-24 11:04:54--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P13_10.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 832464 (813K) [application/json]
# Saving to: ‘P13_10.json’
#
# P13_10.json         100%[===================>] 812.95K   774KB/s    in 1.1s
#
# 2024-12-24 11:04:55 (774 KB/s) - ‘P13_10.json’ saved [832464/832464]
#
# --2024-12-24 11:04:55--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P14_05.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 464879 (454K) [application/json]
# Saving to: ‘P14_05.json’
#
# P14_05.json         100%[===================>] 453.98K   688KB/s    in 0.7s
#
# 2024-12-24 11:04:57 (688 KB/s) - ‘P14_05.json’ saved [464879/464879]
#
# --2024-12-24 11:04:57--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P15_02.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2698882 (2.6M) [application/json]
# Saving to: ‘P15_02.json’
#
# P15_02.json         100%[===================>]   2.57M   902KB/s    in 2.9s
#
# 2024-12-24 11:05:00 (902 KB/s) - ‘P15_02.json’ saved [2698882/2698882]
#
# --2024-12-24 11:05:00--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P17_01.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 357042 (349K) [application/json]
# Saving to: ‘P17_01.json’
#
# P17_01.json         100%[===================>] 348.67K   656KB/s    in 0.5s
#
# 2024-12-24 11:05:02 (656 KB/s) - ‘P17_01.json’ saved [357042/357042]
#
# --2024-12-24 11:05:02--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P18_03.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3330141 (3.2M) [application/json]
# Saving to: ‘P18_03.json’
#
# P18_03.json         100%[===================>]   3.18M   912KB/s    in 3.6s
#
# 2024-12-24 11:05:06 (912 KB/s) - ‘P18_03.json’ saved [3330141/3330141]
#
# --2024-12-24 11:05:06--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P18_06.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1850250 (1.8M) [application/json]
# Saving to: ‘P18_06.json’
#
# P18_06.json         100%[===================>]   1.76M   857KB/s    in 2.1s
#
# 2024-12-24 11:05:09 (857 KB/s) - ‘P18_06.json’ saved [1850250/1850250]
#
# --2024-12-24 11:05:09--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P18_07.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1161213 (1.1M) [application/json]
# Saving to: ‘P18_07.json’
#
# P18_07.json         100%[===================>]   1.11M   863KB/s    in 1.3s
#
# 2024-12-24 11:05:11 (863 KB/s) - ‘P18_07.json’ saved [1161213/1161213]
#
# --2024-12-24 11:05:11--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P20_03.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1469147 (1.4M) [application/json]
# Saving to: ‘P20_03.json’
#
# P20_03.json         100%[===================>]   1.40M   836KB/s    in 1.7s
#
# 2024-12-24 11:05:13 (836 KB/s) - ‘P20_03.json’ saved [1469147/1469147]
#
# --2024-12-24 11:05:13--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/annotations/train/P22_01.json
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 163857679 (156M) [application/zip]
# Saving to: ‘P22_01.zip’
#
# P22_01.zip          100%[===================>] 156.27M   976KB/s    in 2m 50s
#
# 2024-12-24 13:29:02 (944 KB/s) - ‘P22_01.zip’ saved [163857679/163857679]
#
# --2024-12-24 13:29:03--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P22/P22_07.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 340119408 (324M) [application/zip]
# Saving to: ‘P22_07.zip’
#
# P22_07.zip          100%[===================>] 324.36M   972KB/s    in 5m 47s
#
# 2024-12-24 13:34:50 (957 KB/s) - ‘P22_07.zip’ saved [340119408/340119408]
#
# --2024-12-24 13:34:50--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P22/P22_117.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 200058788 (191M) [application/zip]
# Saving to: ‘P22_117.zip’
#
# P22_117.zip         100%[===================>] 190.79M   974KB/s    in 3m 22s
#
# 2024-12-24 13:38:13 (966 KB/s) - ‘P22_117.zip’ saved [200058788/200058788]
#
# --2024-12-24 13:38:14--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P23/P23_02.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 96786001 (92M) [application/zip]
# Saving to: ‘P23_02.zip’
#
# P23_02.zip          100%[===================>]  92.30M   978KB/s    in 98s
#
# 2024-12-24 13:39:52 (966 KB/s) - ‘P23_02.zip’ saved [96786001/96786001]
#
# --2024-12-24 13:39:52--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P23/P23_05.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56702105 (54M) [application/zip]
# Saving to: ‘P23_05.zip’
#
# P23_05.zip          100%[===================>]  54.08M   980KB/s    in 57s
#
# 2024-12-24 13:40:50 (966 KB/s) - ‘P23_05.zip’ saved [56702105/56702105]
#
# --2024-12-24 13:40:50--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P24/P24_05.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 189278429 (181M) [application/zip]
# Saving to: ‘P24_05.zip’
#
# P24_05.zip          100%[===================>] 180.51M   974KB/s    in 3m 13s
#
# 2024-12-24 13:44:04 (958 KB/s) - ‘P24_05.zip’ saved [189278429/189278429]
#
# --2024-12-24 13:44:04--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P24/P24_08.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 216926340 (207M) [application/zip]
# Saving to: ‘P24_08.zip’
#
# P24_08.zip          100%[===================>] 206.88M   973KB/s    in 3m 41s
#
# 2024-12-24 13:47:46 (958 KB/s) - ‘P24_08.zip’ saved [216926340/216926340]
#
# --2024-12-24 13:47:46--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P25/P25_107.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 228651964 (218M) [application/zip]
# Saving to: ‘P25_107.zip’
#
# P25_107.zip         100%[===================>] 218.06M   968KB/s    in 3m 51s
#
# 2024-12-24 13:51:38 (967 KB/s) - ‘P25_107.zip’ saved [228651964/228651964]
#
# --2024-12-24 13:51:38--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P26/P26_110.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31041266 (30M) [application/zip]
# Saving to: ‘P26_110.zip’
#
# P26_110.zip         100%[===================>]  29.60M   965KB/s    in 32s
#
# 2024-12-24 13:52:10 (954 KB/s) - ‘P26_110.zip’ saved [31041266/31041266]
#
# --2024-12-24 13:52:10--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P27/P27_101.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 379073465 (362M) [application/zip]
# Saving to: ‘P27_101.zip’
#
# P27_101.zip         100%[===================>] 361.51M   980KB/s    in 6m 26s
#
# 2024-12-24 13:58:36 (960 KB/s) - ‘P27_101.zip’ saved [379073465/379073465]
#
# --2024-12-24 13:58:37--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P28/P28_06.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 100005154 (95M) [application/zip]
# Saving to: ‘P28_06.zip’
#
# P28_06.zip          100%[===================>]  95.37M   964KB/s    in 1m 42s
#
# 2024-12-24 14:00:19 (956 KB/s) - ‘P28_06.zip’ saved [100005154/100005154]
#
# --2024-12-24 14:00:19--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P28/P28_101.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 95050818 (91M) [application/zip]
# Saving to: ‘P28_101.zip’
#
# P28_101.zip         100%[===================>]  90.65M   986KB/s    in 96s
#
# 2024-12-24 14:01:56 (966 KB/s) - ‘P28_101.zip’ saved [95050818/95050818]
#
# --2024-12-24 14:01:56--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P28/P28_103.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 297409266 (284M) [application/zip]
# Saving to: ‘P28_103.zip’
#
# P28_103.zip         100%[===================>] 283.63M   969KB/s    in 5m 2s
#
# 2024-12-24 14:06:59 (962 KB/s) - ‘P28_103.zip’ saved [297409266/297409266]
#
# --2024-12-24 14:06:59--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P28/P28_109.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32582330 (31M) [application/zip]
# Saving to: ‘P28_109.zip’
#
# P28_109.zip         100%[===================>]  31.07M   987KB/s    in 33s
#
# 2024-12-24 14:07:33 (961 KB/s) - ‘P28_109.zip’ saved [32582330/32582330]
#
# --2024-12-24 14:07:33--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P28/P28_110.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16669824 (16M) [application/zip]
# Saving to: ‘P28_110.zip’
#
# P28_110.zip         100%[===================>]  15.90M   975KB/s    in 17s
#
# 2024-12-24 14:07:51 (942 KB/s) - ‘P28_110.zip’ saved [16669824/16669824]
#
# --2024-12-24 14:07:51--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P28/P28_112.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 67397986 (64M) [application/zip]
# Saving to: ‘P28_112.zip’
#
# P28_112.zip         100%[===================>]  64.28M   987KB/s    in 68s
#
# 2024-12-24 14:09:00 (966 KB/s) - ‘P28_112.zip’ saved [67397986/67397986]
#
# --2024-12-24 14:09:00--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P28/P28_113.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 108852456 (104M) [application/zip]
# Saving to: ‘P28_113.zip’
#
# P28_113.zip         100%[===================>] 103.81M   951KB/s    in 1m 51s
#
# 2024-12-24 14:10:51 (960 KB/s) - ‘P28_113.zip’ saved [108852456/108852456]
#
# --2024-12-24 14:10:51--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P28/P28_13.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30381668 (29M) [application/zip]
# Saving to: ‘P28_13.zip’
#
# P28_13.zip          100%[===================>]  28.97M   984KB/s    in 31s
#
# 2024-12-24 14:11:23 (956 KB/s) - ‘P28_13.zip’ saved [30381668/30381668]
#
# --2024-12-24 14:11:23--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P28/P28_14.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60046876 (57M) [application/zip]
# Saving to: ‘P28_14.zip’
#
# P28_14.zip          100%[===================>]  57.26M   984KB/s    in 61s
#
# 2024-12-24 14:12:25 (957 KB/s) - ‘P28_14.zip’ saved [60046876/60046876]
#
# --2024-12-24 14:12:25--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P30/P30_05.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 411731921 (393M) [application/zip]
# Saving to: ‘P30_05.zip’
#
# P30_05.zip          100%[===================>] 392.66M   969KB/s    in 6m 59s
#
# 2024-12-24 14:19:25 (960 KB/s) - ‘P30_05.zip’ saved [411731921/411731921]
#
# --2024-12-24 14:19:25--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P30/P30_101.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 119736200 (114M) [application/zip]
# Saving to: ‘P30_101.zip’
#
# P30_101.zip         100%[===================>] 114.19M   531KB/s    in 2m 4s
#
# 2024-12-24 14:21:30 (940 KB/s) - ‘P30_101.zip’ saved [119736200/119736200]
#
# --2024-12-24 14:21:30--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P30/P30_107.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 320527102 (306M) [application/zip]
# Saving to: ‘P30_107.zip’
#
# P30_107.zip         100%[===================>] 305.68M   992KB/s    in 5m 27s
#
# 2024-12-24 14:26:57 (959 KB/s) - ‘P30_107.zip’ saved [320527102/320527102]
#
# --2024-12-24 14:26:57--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P30/P30_111.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 249982028 (238M) [application/zip]
# Saving to: ‘P30_111.zip’
#
# P30_111.zip         100%[===================>] 238.40M   975KB/s    in 4m 13s
#
# 2024-12-24 14:31:11 (966 KB/s) - ‘P30_111.zip’ saved [249982028/249982028]
#
# --2024-12-24 14:31:11--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P30/P30_112.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16712577 (16M) [application/zip]
# Saving to: ‘P30_112.zip’
#
# P30_112.zip         100%[===================>]  15.94M   980KB/s    in 17s
#
# 2024-12-24 14:31:29 (945 KB/s) - ‘P30_112.zip’ saved [16712577/16712577]
#
# --2024-12-24 14:31:29--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P32/P32_01.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31235257 (30M) [application/zip]
# Saving to: ‘P32_01.zip’
#
# P32_01.zip          100%[===================>]  29.79M   985KB/s    in 32s
#
# 2024-12-24 14:32:01 (961 KB/s) - ‘P32_01.zip’ saved [31235257/31235257]
#
# --2024-12-24 14:32:01--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P35/P35_105.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 265810461 (253M) [application/zip]
# Saving to: ‘P35_105.zip’
#
# P35_105.zip         100%[===================>] 253.50M   965KB/s    in 4m 33s
#
# 2024-12-24 14:36:35 (951 KB/s) - ‘P35_105.zip’ saved [265810461/265810461]
#
# --2024-12-24 14:36:35--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P35/P35_109.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 157075565 (150M) [application/zip]
# Saving to: ‘P35_109.zip’
#
# P35_109.zip         100%[===================>] 149.80M   960KB/s    in 2m 39s
#
# 2024-12-24 14:39:14 (967 KB/s) - ‘P35_109.zip’ saved [157075565/157075565]
#
# --2024-12-24 14:39:14--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P37/P37_101.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 157190020 (150M) [application/zip]
# Saving to: ‘P37_101.zip’
#
# P37_101.zip         100%[===================>] 149.91M   965KB/s    in 2m 40s
#
# 2024-12-24 14:41:55 (961 KB/s) - ‘P37_101.zip’ saved [157190020/157190020]
#
# --2024-12-24 14:41:55--  https://data.bris.ac.uk/datasets/2v6cgv1x04ol22qp9rm9x2j6a7/GroundTruth-SparseAnnotations/rgb_frames/train/P37/P37_103.zip
# Resolving data.bris.ac.uk (data.bris.ac.uk)... 137.222.0.78
# Connecting to data.bris.ac.uk (data.bris.ac.uk)|137.222.0.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38127632 (36M) [application/zip]
# Saving to: ‘P37_103.zip’
#
# P37_103.zip         100%[===================>]  36.36M   964KB/s    in 39s
#
# 2024-12-24 14:42:35 (959 KB/s) - ‘P37_103.zip’ saved [38127632/38127632]
#
# /content

# %%
# If left hand in json file (for now just left) has an object in contact:
#     Get corresponding image frame and place into TRUE folder
# Else if it is (definitely) not in contact:
#     Place it in the FALSE folder
# Else (i.e. inconclusive or in contact but not with a labelled object):
#     Discard

def image_sorter(json_path, zip_path, true_folder, false_folder):

    # Load the JSON data
    try:
        with open(json_path, 'r') as file:
            data = json.load(file)
    except (json.JSONDecodeError, KeyError) as e:
        print(f"Error loading JSON file {json_path}: {e}")
        return

    # Open the ZIP file
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        file_list = zip_ref.namelist()  # Get all file names in the ZIP

        # Track images that are added to the TRUE folder
        true_images = set()
        excluded_images = set()

        # Check for annotations with hand contact
        for video_annotation in data['video_annotations']:
            for annotation in video_annotation['annotations']:
                # Handle left-hand annotations
                if annotation['name'] == 'right hand':
                    if annotation['in_contact_object'] in ['inconclusive', 'none-of-the-above']:
                        # Exclude these cases
                        excluded_images.add(video_annotation['image']['name'])
                    elif annotation['in_contact_object'] not in ['hand-not-in-contact']:
                        # Add to TRUE if valid
                        image_name = video_annotation['image']['name']
                        for file_name in file_list:
                            if file_name.endswith(image_name) and file_name not in true_images:
                                zip_ref.extract(file_name, true_folder)
                                true_images.add(file_name)

        # Add remaining images to the FALSE folder
        for file_name in file_list:
            # Exclude images that are flagged for exclusion or already added to TRUE
            if file_name not in true_images and file_name not in excluded_images:
                zip_ref.extract(file_name, false_folder)

# %%
true_folder = "TRUE_RIGHT"
false_folder = "FALSE_RIGHT"

os.makedirs(true_folder, exist_ok=True)
os.makedirs(false_folder, exist_ok=True)

annotations_folder = 'annotations_train'
images_folder = 'images_train'

json_files = sorted([f for f in os.listdir(annotations_folder) if f.endswith('.json')])
zip_files = sorted([f for f in os.listdir(images_folder) if f.endswith('.zip')])

if len(json_files) != len(zip_files):
    print("Warning: Mismatch between JSON and ZIP files.")

# zip() combines two or more iterables element-wise into a single iterable of tuples
# has nothing to do with zip files
for json_file, zip_file in zip(json_files, zip_files):

    json_path = os.path.join(annotations_folder, json_file)
    zip_path = os.path.join(images_folder, zip_file)

    image_sorter(json_path, zip_path, true_folder, false_folder)

# %%
# Paths in Google Drive
drive_true_folder = '/content/drive/My Drive/true_right_images.zip'
drive_false_folder = '/content/drive/My Drive/false_right_images.zip'

# Compress and save to Google Drive
# NOTE - Ensure there is adequate space in Drive first
shutil.make_archive(drive_true_folder.replace('.zip', ''), 'zip', true_folder)
shutil.make_archive(drive_false_folder.replace('.zip', ''), 'zip', false_folder)

print("Folders saved to Google Drive.")
# Out:
# Folders saved to Google Drive.

# %%
# Make a tensorflow-friendly dataset
# !mkdir data
# !mv TRUE_RIGHT data/
# !mv FALSE_RIGHT data/

# %%
# Load the dataset into tensorflow
data = tf.keras.utils.image_dataset_from_directory('data')

# Scale down the pixel intensitites from 0-255 to 0-1
data = data.map(lambda x,y: (x/255, y))
scaled_iterator = data.as_numpy_iterator()
batch = scaled_iterator.next()

# Partition into training and testing data
train_size = int(len(data)*0.7)
val_size = int(len(data)*0.2)
test_size = int(len(data)*0.1)

train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)
# Out:
# Found 29703 files belonging to 2 classes.

# %%
# Create the CNN
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

model = Sequential()

model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())

model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 254, 254, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 127, 127, 16)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 125, 125, 32)        │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 62, 62, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 60, 60, 16)          │           4,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 30, 30, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 14400)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │       3,686,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,696,625 (14.10 MB)
#  Trainable params: 3,696,625 (14.10 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
logdir = 'logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 1903s 3s/step - accuracy: 0.7607 - loss: 0.5486 - val_accuracy: 0.7704 - val_loss: 0.5329
# Epoch 2/20
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 1905s 3s/step - accuracy: 0.7772 - loss: 0.4813 - val_accuracy: 0.7833 - val_loss: 0.4611
# Epoch 3/20
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 1871s 3s/step - accuracy: 0.8023 - loss: 0.4328 - val_accuracy: 0.7966 - val_loss: 0.4577
# Epoch 4/20
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 1890s 3s/step - accuracy: 0.8421 - loss: 0.3581 - val_accuracy: 0.7976 - val_loss: 0.4906
# Epoch 5/20
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 1883s 3s/step - accuracy: 0.8957 - loss: 0.2531 - val_accuracy: 0.7691 - val_loss: 0.6800
# Epoch 6/20
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 1888s 3s/step - accuracy: 0.9383 - loss: 0.1599 - val_accuracy: 0.7828 - val_loss: 0.8964
# Epoch 7/20
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 1890s 3s/step - accuracy: 0.9691 - loss: 0.0820 - val_accuracy: 0.7880 - val_loss: 1.1542
# Epoch 8/20
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 1903s 3s/step - accuracy: 0.9803 - loss: 0.0602 - val_accuracy: 0.7796 - val_loss: 1.3161
# Epoch 9/20
# 239/650 ━━━━━━━━━━━━━━━━━━━━ 15:16 2s/step - accuracy: 0.9848 - loss: 0.0456
